# %%
import pandas as pd

train_df = pd.read_csv("../data/train.csv")
val_df = pd.read_csv("../data/validation.csv")
test_df = pd.read_csv("../data/test.csv")

print("Train Shape:", train_df.shape)
print("Validation Shape:", val_df.shape)
print("Test Shape:", test_df.shape)
# Out:
# Train Shape: (5491971, 47)
# Validation Shape: (1176851, 47)
# Test Shape: (1176851, 47)

# %%
train_df.head()
# Out:
#    flow_duration  Header_Length  Protocol Type  Duration       Rate  \
# 0       0.000000         757.00           6.00     64.00  23.671858
# 1       0.000000          54.00           6.00     64.00   2.393046
# 2       0.033982          56.78           6.11     64.64   1.192715
# 3       0.000000           0.00          47.00     64.00   9.841972
# 4       3.944828         108.00           6.00     64.00   0.506993
#
#        Srate  Drate  fin_flag_number  syn_flag_number  rst_flag_number  ...  \
# 0  23.671858    0.0              0.0              0.0              0.0  ...
# 1   2.393046    0.0              0.0              1.0              0.0  ...
# 2   1.192715    0.0              0.0              0.0              0.0  ...
# 3   9.841972    0.0              0.0              0.0              0.0  ...
# 4   0.506993    0.0              0.0              1.0              0.0  ...
#
#           Std  Tot size           IAT  Number   Magnitue      Radius  \
# ...

# %%
train_df["label"].value_counts()
# Out:
# label
# DDoS-ICMP_Flood            848088
# DDoS-UDP_Flood             637558
# DDoS-TCP_Flood             528499
# DDoS-PSHACK_Flood          481254
# DDoS-SYN_Flood             478653
# DDoS-RSTFINFlood           475441
# DDoS-SynonymousIP_Flood    422083
# DoS-UDP_Flood              390422
# DoS-TCP_Flood              314174
# DoS-SYN_Flood              237573
# BenignTraffic              129538
# Mirai-greeth_flood         116133
# Mirai-udpplain             104814
# Mirai-greip_flood           88821
# DDoS-ICMP_Fragmentation     53046
# MITM-ArpSpoofing            36316
# DDoS-UDP_Fragmentation      34169
# DDoS-ACK_Fragmentation      33581
# DNS_Spoofing                21214
# Recon-HostDiscovery         15737
# Recon-OSScan                11587
# Recon-PortScan               9648
# DoS-HTTP_Flood               8487
# VulnerabilityScan            4396
# DDoS-HTTP_Flood              3371
# DDoS-SlowLoris               2757
# DictionaryBruteForce         1541
# ...

# %%
train_df["label"].value_counts().head(20)
# Out:
# label
# DDoS-ICMP_Flood            848088
# DDoS-UDP_Flood             637558
# DDoS-TCP_Flood             528499
# DDoS-PSHACK_Flood          481254
# DDoS-SYN_Flood             478653
# DDoS-RSTFINFlood           475441
# DDoS-SynonymousIP_Flood    422083
# DoS-UDP_Flood              390422
# DoS-TCP_Flood              314174
# DoS-SYN_Flood              237573
# BenignTraffic              129538
# Mirai-greeth_flood         116133
# Mirai-udpplain             104814
# Mirai-greip_flood           88821
# DDoS-ICMP_Fragmentation     53046
# MITM-ArpSpoofing            36316
# DDoS-UDP_Fragmentation      34169
# DDoS-ACK_Fragmentation      33581
# DNS_Spoofing                21214
# Recon-HostDiscovery         15737
# Name: count, dtype: int64

# %%
print("Total Classes:", train_df["label"].nunique())
# Out:
# Total Classes: 34

# %%
print("Total Classes:", train_df["label"].nunique())
train_df["label"].value_counts().head(20)
# Out:
# Total Classes: 34
# label
# DDoS-ICMP_Flood            848088
# DDoS-UDP_Flood             637558
# DDoS-TCP_Flood             528499
# DDoS-PSHACK_Flood          481254
# DDoS-SYN_Flood             478653
# DDoS-RSTFINFlood           475441
# DDoS-SynonymousIP_Flood    422083
# DoS-UDP_Flood              390422
# DoS-TCP_Flood              314174
# DoS-SYN_Flood              237573
# BenignTraffic              129538
# Mirai-greeth_flood         116133
# Mirai-udpplain             104814
# Mirai-greip_flood           88821
# DDoS-ICMP_Fragmentation     53046
# MITM-ArpSpoofing            36316
# DDoS-UDP_Fragmentation      34169
# DDoS-ACK_Fragmentation      33581
# DNS_Spoofing                21214
# Recon-HostDiscovery         15737
# Name: count, dtype: int64

# %%
missing_values = train_df.isnull().sum()

missing_values[missing_values > 0]
# Out:
# Series([], dtype: int64)

# %%
train_df.dtypes
# Out:
# flow_duration      float64
# Header_Length      float64
# Protocol Type      float64
# Duration           float64
# Rate               float64
# Srate              float64
# Drate              float64
# fin_flag_number    float64
# syn_flag_number    float64
# rst_flag_number    float64
# psh_flag_number    float64
# ack_flag_number    float64
# ece_flag_number    float64
# cwr_flag_number    float64
# ack_count          float64
# syn_count          float64
# fin_count          float64
# urg_count          float64
# rst_count          float64
# HTTP               float64
# HTTPS              float64
# DNS                float64
# Telnet             float64
# SMTP               float64
# SSH                float64
# IRC                float64
# TCP                float64
# UDP                float64
# DHCP               float64
# ARP                float64
# ICMP               float64
# IPv                float64
# LLC                float64
# Tot sum            float64
# ...

# %%
train_df.dtypes.value_counts()
# Out:
# float64    46
# str         1
# Name: count, dtype: int64

# %%
train_df.describe()
# Out:
#        flow_duration  Header_Length  Protocol Type      Duration  \
# count   5.491971e+06   5.491971e+06   5.491971e+06  5.491971e+06
# mean    5.657345e+00   7.687147e+04   9.066457e+00  6.636141e+01
# std     2.749157e+02   4.615005e+05   8.943837e+00  1.406518e+01
# min     0.000000e+00   0.000000e+00   0.000000e+00  0.000000e+00
# 25%     0.000000e+00   5.400000e+01   6.000000e+00  6.400000e+01
# 50%     0.000000e+00   5.400000e+01   6.000000e+00  6.400000e+01
# 75%     1.050286e-01   3.001300e+02   1.444000e+01  6.400000e+01
# max     9.943576e+04   9.890105e+06   4.700000e+01  2.550000e+02
#
#                Rate         Srate         Drate  fin_flag_number  \
# count  5.491971e+06  5.491971e+06  5.491971e+06     5.491971e+06
# mean   9.049942e+03  9.049942e+03  3.229612e-06     8.650082e-02
# std    9.986400e+04  9.986400e+04  1.848825e-03     2.811022e-01
# min    0.000000e+00  0.000000e+00  0.000000e+00     0.000000e+00
# ...

# %%
benign_count = (train_df["label"] == "BenignTraffic").sum()
attack_count = len(train_df) - benign_count

print("Benign:", benign_count)
print("Attack:", attack_count)
print("Attack %:", round((attack_count/len(train_df))*100, 2))
# Out:
# Benign: 129538
# Attack: 5362433
# Attack %: 97.64

# %%
print(train_df.nunique().sort_values())
# Out:
# IRC                      1
# Telnet                   1
# fin_flag_number          2
# psh_flag_number          2
# ack_flag_number          2
# syn_flag_number          2
# cwr_flag_number          2
# ece_flag_number          2
# DNS                      2
# SSH                      2
# TCP                      2
# SMTP                     2
# HTTP                     2
# HTTPS                    2
# rst_flag_number          2
# DHCP                     2
# IPv                      2
# ARP                      2
# ICMP                     2
# UDP                      2
# LLC                      2
# label                   34
# Number                  96
# Weight                 102
# Drate                  303
# ack_count              437
# fin_count              749
# Variance               843
# syn_count             1269
# Protocol Type         4704
# Duration             12030
# urg_count            20250
# rst_count            49638
# Min                  52321
# ...

# %%
for col in train_df.columns:
    if train_df[col].nunique() == 1:
        print(col)
# Out:
# Telnet
# IRC

# %%
train_df.describe().T[["min", "max"]]
# Out:
#                        min           max
# flow_duration     0.000000  9.943576e+04
# Header_Length     0.000000  9.890105e+06
# Protocol Type     0.000000  4.700000e+01
# Duration          0.000000  2.550000e+02
# Rate              0.000000  8.388608e+06
# Srate             0.000000  8.388608e+06
# Drate             0.000000  2.679210e+00
# fin_flag_number   0.000000  1.000000e+00
# syn_flag_number   0.000000  1.000000e+00
# rst_flag_number   0.000000  1.000000e+00
# psh_flag_number   0.000000  1.000000e+00
# ack_flag_number   0.000000  1.000000e+00
# ece_flag_number   0.000000  1.000000e+00
# cwr_flag_number   0.000000  1.000000e+00
# ack_count         0.000000  5.700000e+00
# syn_count         0.000000  1.261000e+01
# fin_count         0.000000  8.243000e+01
# urg_count         0.000000  4.167700e+03
# rst_count         0.000000  9.586500e+03
# HTTP              0.000000  1.000000e+00
# HTTPS             0.000000  1.000000e+00
# DNS               0.000000  1.000000e+00
# ...
